# %%
from __future__ import division

import numpy as np
import matplotlib.pyplot as plt

import pydy
import sympy as sym
import sympy.physics.mechanics as me

from scipy.linalg import solve, lstsq
from scipy.integrate import odeint

import time
import functools

me.Vector.simp = False  # to increase computation speed

from sympy.physics.vector import init_vprinting
init_vprinting()

from matplotlib import animation
from matplotlib.patches import Ellipse, Rectangle

from IPython.html import widgets
from IPython.html.widgets import interact, interactive

from pydy_code_gen.code import generate_ode_function

# %%
from IPython.display import Image
Image(filename='snake-schematic.png')

# %%
n = 2

# dynamic variables
q = me.dynamicsymbols('q:' + str(n + 2))
u = me.dynamicsymbols('u:' + str(n + 2))
T = me.dynamicsymbols('T:' + str(n + 1))

# variables for bodies
g, t = sym.symbols('g t')
m = sym.symbols('m:' + str(n))
l = sym.symbols('l:' + str(n))
Izz = sym.symbols('I_zz_:' + str(n))

# frames
frames = [me.ReferenceFrame('fr_N')]
for i in range(n):
    name = 'fr_' + str(i)
    frame = frames[i].orientnew(name, 'Axis', [q[i], frames[i].z])
    frame.set_ang_vel(frames[i], u[i] * frames[i].z)
    frames.append(frame)
    
# origin of inertial frame
joints = [me.Point('N_or')]
joints[0].set_vel(frames[0], 0)

# joints
for i in range(n + 1):
    name = 'jt_' + str(i)
    if i == 0:
        joint = joints[i].locatenew(name, q[-2] * frames[0].x + q[-1] * frames[0].y)
        joint.set_vel(frames[0], u[-2] * frames[0].x + u[-1] * frames[0].y)
    else:
        joint = joints[i].locatenew(name, l[i - 1] * frames[i].x)
        joint.v2pt_theory(joints[i], frames[0], frames[i])
    joints.append(joint)

# mass centers
mc = []
for i in range(n):
    name = 'mc_' + str(i)
    mcent = joints[i + 1].locatenew(name, l[i] / 2 * frames[i + 1].x)
    mcent.v2pt_theory(joints[i + 1], frames[0], frames[i + 1])
    mc.append(mcent)

# inertia dyads
dyads = []
for i in range(n):
    dyad = (me.inertia(frames[i + 1], 0, 0, Izz[i]), mc[i])
    dyads.append(dyad)

# bodies
bodies = []
for i in range(n):
    name = 'bd_' + str(i)
    body = me.RigidBody(name, mc[i], frames[i + 1], m[i], dyads[i])
    bodies.append(body)

# kinematic differential equations
kd = []
for i in range(n + 2):
    kd.append(q[i].diff(t) - u[i])

forces = []
for i in range(n):
    forces.append((mc[i], -m[i] * g * frames[0].z))
    
torques = []
for i in range(n):
    torques.append((frames[i + 1], (T[i] - T[i + 1]) * frames[0].z))
    
fl = forces + torques

# %%
##
# this is like the lizard
##
n = 2

# dynamic variables
q = me.dynamicsymbols('q:' + str(n))
u = me.dynamicsymbols('u:' + str(n))
T = me.dynamicsymbols('T:' + str(n + 1))

# variables for bodies
g, t = sym.symbols('g t')
m = sym.symbols('m:' + str(n))
l = sym.symbols('l:' + str(n))
Izz = sym.symbols('I_zz_:' + str(n))

# frames
frames = [me.ReferenceFrame('fr_N')]
for i in range(n):
    name = 'fr_' + str(i)
    frame = frames[i].orientnew(name, 'Axis', [q[i], frames[0].z])
    frame.set_ang_vel(frames[i], u[i] * frames[0].z)
    frames.append(frame)
    
# origin of inertial frame
joints = [me.Point('N_or')]
joints[0].set_vel(frames[0], 0)

# joints
for i in range(n + 1):
    name = 'jt_' + str(i)
    joint = joints[i].locatenew(name, l[i - 1] * frames[i].x)
    joint.v2pt_theory(joints[i], frames[0], frames[i])
    joints.append(joint)

# mass centers
mc = []
for i in range(n):
    name = 'mc_' + str(i)
    mcent = joints[i + 1].locatenew(name, l[i] / 2 * frames[i + 1].x)
    mcent.v2pt_theory(joints[i + 1], frames[0], frames[i + 1])
    mc.append(mcent)

# inertia dyads
dyads = []
for i in range(n):
    dyad = (me.inertia(frames[i + 1], 0, 0, Izz[i]), mc[i])
    dyads.append(dyad)

# bodies
bodies = []
for i in range(n):
    name = 'bd_' + str(i)
    body = me.RigidBody(name, mc[i], frames[i + 1], m[i], dyads[i])
    bodies.append(body)

# kinematic differential equations
kd = []
for i in range(n):
    kd.append(q[i].diff(t) - u[i])

forces = []
for i in range(n):
    forces.append((mc[i], -m[i] * g * frames[0].z))
    
torques = []
for i in range(n):
    torques.append((frames[i + 1], (T[i] - T[i + 1]) * frames[0].z))
    
fl = forces + torques

# %%
# equations of motion using Kane's method
kane = me.KanesMethod(frame=frames[0],
                      q_ind=q,
                      u_ind=u,
                      kd_eqs=kd,
                      q_dependent=[],
                      configuration_constraints=[],
                      u_dependent=[],
                      velocity_constraints=[])

now = time.time()
(fr, frstar) = kane.kanes_equations(fl, bodies)
kanezero = fr + frstar
print('elapsed time: {0:.3f} sec'.format(time.time() - now))
# Out:
# elapsed time: 0.347 sec

# %%
sym.trigsimp(frstar[0])
# Out:
#                   2                      2
# l₀⋅l₁⋅m₁⋅(u₀ + u₁) ⋅sin(q₁)   l₀⋅l₁⋅m₁⋅u₀ ⋅sin(q₁)   ⎛         l₁⋅m₁⋅(2⋅l₀⋅cos
# ─────────────────────────── - ──────────────────── - ⎜I_zz_1 + ───────────────
#              2                         2             ⎝                     4
#
#
# (q₁) + l₁)⎞       ⎛  l₀⋅m₀⋅sin(q₀)      ⎛              l₁⋅sin(q₀ + q₁)⎞⎞
# ──────────⎟⋅u₁̇ - ⎜- ───────────── + m₁⋅⎜-l₀⋅sin(q₀) - ───────────────⎟⎟⋅u₂̇ -
#           ⎠       ⎝        2            ⎝                     2       ⎠⎠
#
#                                                            ⎛
#  ⎛l₀⋅m₀⋅cos(q₀)      ⎛             l₁⋅cos(q₀ + q₁)⎞⎞       ⎜
#  ⎜───────────── + m₁⋅⎜l₀⋅cos(q₀) + ───────────────⎟⎟⋅u₃̇ - ⎜I_zz_0 + I_zz_1 +
#  ⎝      2            ⎝                    2       ⎠⎠       ⎝
#
#   2         ⎛                        2⎞⎞
# l₀ ⋅m₀      ⎜  2                   l₁ ⎟⎟
# ────── + m₁⋅⎜l₀  + l₀⋅l₁⋅cos(q₁) + ───⎟⎟⋅u₀̇
#   4         ⎝                       4 ⎠⎠

# %%
fr[1]
# Out:
# T₁ - T₂

# %%
# Out:
# u₁̇

# %%
now = time.time()
soln = sym.solve(kanezero, u[1].diff(t))
print('elapsed time: {0:.3f} sec'.format(time.time() - now))
# Out:
# elapsed time: 68.568 sec

# %%
now = time.time()
mass_matrix = kane.mass_matrix_full
forcing_vector = kane.forcing_full
print('Equation rearranging:  {0:.3f} sec'.format(time.time() - now))
# Out:
# Equation rearranging:  0.005 sec

# %%
forcing_vector
# Out:
# ⎡                                             u₀
# ⎢
# ⎢                                             u₁
# ⎢
# ⎢                                             u₂
# ⎢
# ⎢                                             u₃
# ⎢
# ⎢                                  2                      2
# ⎢                l₀⋅l₁⋅m₁⋅(u₀ + u₁) ⋅sin(q₁)   l₀⋅l₁⋅m₁⋅u₀ ⋅sin(q₁)
# ⎢                ─────────────────────────── - ──────────────────── + T₀ - T₂
# ⎢                             2                         2
# ⎢
# ⎢                                           2
# ⎢                                l₀⋅l₁⋅m₁⋅u₀ ⋅sin(q₁)
# ⎢                              - ──────────────────── + T₁ - T₂
# ⎢                                         2
# ⎢
# ⎢        2
# ⎢l₀⋅m₀⋅u₀ ⋅cos(q₀)           2           l₁⋅m₁⋅(-sin(q₀)⋅sin(q₁) + cos(q₀)⋅cos
# ⎢───────────────── + l₀⋅m₁⋅u₀ ⋅cos(q₀) + ─────────────────────────────────────
# ⎢        2                                                         2
# ⎢
# ⎢        2
# ⎢l₀⋅m₀⋅u₀ ⋅sin(q₀)           2           l₁⋅m₁⋅(sin(q₀)⋅cos(q₁) + sin(q₁)⋅cos(
# ⎢───────────────── + l₀⋅m₁⋅u₀ ⋅sin(q₀) + ─────────────────────────────────────
# ⎣        2                                                        2
#
#                 ⎤
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                2⎥
# (q₁))⋅(u₀ + u₁) ⎥
# ────────────────⎥
#                 ⎥
#                 ⎥
#               2 ⎥
# q₀))⋅(u₀ + u₁)  ⎥
# ─────────────── ⎥
#                 ⎦

# %%
mass_matrix[5, :]
# Out:
# ⎡                        ⎛                  2⎞             2
# ⎢                        ⎜l₀⋅l₁⋅cos(q₁)   l₁ ⎟           l₁ ⋅m₁  l₁⋅m₁⋅(-sin(q
# ⎢0  0  0  0  I_zz_1 + m₁⋅⎜───────────── + ───⎟  I_zz_1 + ──────  ─────────────
# ⎣                        ⎝      2          4 ⎠             4
#
#                                                                          ⎤
# ₀)⋅cos(q₁) - sin(q₁)⋅cos(q₀))  l₁⋅m₁⋅(-sin(q₀)⋅sin(q₁) + cos(q₀)⋅cos(q₁))⎥
# ─────────────────────────────  ──────────────────────────────────────────⎥
#        2                                           2                     ⎦

# %%
mass_matrix.shape
# Out:
# (8, 8)

# %%
kane.forcing
# Out:
# ⎡                                  2                      2
# ⎢                l₀⋅l₁⋅m₁⋅(u₀ + u₁) ⋅sin(q₁)   l₀⋅l₁⋅m₁⋅u₀ ⋅sin(q₁)
# ⎢                ─────────────────────────── - ──────────────────── + T₀ - T₂
# ⎢                             2                         2
# ⎢
# ⎢                                           2
# ⎢                                l₀⋅l₁⋅m₁⋅u₀ ⋅sin(q₁)
# ⎢                              - ──────────────────── + T₁ - T₂
# ⎢                                         2
# ⎢
# ⎢        2
# ⎢l₀⋅m₀⋅u₀ ⋅cos(q₀)           2           l₁⋅m₁⋅(-sin(q₀)⋅sin(q₁) + cos(q₀)⋅cos
# ⎢───────────────── + l₀⋅m₁⋅u₀ ⋅cos(q₀) + ─────────────────────────────────────
# ⎢        2                                                         2
# ⎢
# ⎢        2
# ⎢l₀⋅m₀⋅u₀ ⋅sin(q₀)           2           l₁⋅m₁⋅(sin(q₀)⋅cos(q₁) + sin(q₁)⋅cos(
# ⎢───────────────── + l₀⋅m₁⋅u₀ ⋅sin(q₀) + ─────────────────────────────────────
# ⎣        2                                                        2
#
#                 ⎤
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                2⎥
# (q₁))⋅(u₀ + u₁) ⎥
# ────────────────⎥
#                 ⎥
#                 ⎥
#               2 ⎥
# q₀))⋅(u₀ + u₁)  ⎥
# ─────────────── ⎥
#                 ⎦

# %%
frstar[1]
# Out:
#              2
#   l₀⋅l₁⋅m₁⋅u₀ ⋅sin(q₁)   l₁⋅m₁⋅(-sin(q₀)⋅sin(q₁) + cos(q₀)⋅cos(q₁))⋅u₃̇   l₁⋅m
# - ──────────────────── - ────────────────────────────────────────────── - ────
#            2                                   2
#
#                                              ⎛           2   ⎞       ⎛
# ₁⋅(-sin(q₀)⋅cos(q₁) - sin(q₁)⋅cos(q₀))⋅u₂̇   ⎜         l₁ ⋅m₁⎟       ⎜
# ────────────────────────────────────────── - ⎜I_zz_1 + ──────⎟⋅u₁̇ - ⎜I_zz_1 +
#                   2                          ⎝           4   ⎠       ⎝
#
#     ⎛                  2⎞⎞
#     ⎜l₀⋅l₁⋅cos(q₁)   l₁ ⎟⎟
#  m₁⋅⎜───────────── + ───⎟⎟⋅u₀̇
#     ⎝      2          4 ⎠⎠

# %%
sym.trigsimp(frstar[1])
# Out:
#              2                                                             ⎛
#   l₀⋅l₁⋅m₁⋅u₀ ⋅sin(q₁)   l₁⋅m₁⋅sin(q₀ + q₁)⋅u₂̇   l₁⋅m₁⋅cos(q₀ + q₁)⋅u₃̇   ⎜
# - ──────────────────── + ────────────────────── - ────────────────────── - ⎜I_
#            2                       2                        2              ⎝
#
#          2   ⎞
#        l₁ ⋅m₁⎟       ⎛         l₁⋅m₁⋅(2⋅l₀⋅cos(q₁) + l₁)⎞
# zz_1 + ──────⎟⋅u₁̇ - ⎜I_zz_1 + ─────────────────────────⎟⋅u₀̇
#          4   ⎠       ⎝                     4            ⎠

# %%
sym.trigsimp(frstar[2])
# Out:
#         2                                              2
# l₀⋅m₀⋅u₀ ⋅cos(q₀)           2           l₁⋅m₁⋅(u₀ + u₁) ⋅cos(q₀ + q₁)   l₁⋅m₁⋅
# ───────────────── + l₀⋅m₁⋅u₀ ⋅cos(q₀) + ───────────────────────────── + ──────
#         2                                             2
#
#
# sin(q₀ + q₁)⋅u₁̇                   ⎛  l₀⋅m₀⋅sin(q₀)      ⎛              l₁⋅sin
# ──────────────── - (m₀ + m₁)⋅u₂̇ - ⎜- ───────────── + m₁⋅⎜-l₀⋅sin(q₀) - ──────
#     2                              ⎝        2            ⎝
#
#
# (q₀ + q₁)⎞⎞
# ─────────⎟⎟⋅u₀̇
#  2       ⎠⎠

# %%
sym.trigsimp(frstar[3])
# Out:
#         2                                              2
# l₀⋅m₀⋅u₀ ⋅sin(q₀)           2           l₁⋅m₁⋅(u₀ + u₁) ⋅sin(q₀ + q₁)   l₁⋅m₁⋅
# ───────────────── + l₀⋅m₁⋅u₀ ⋅sin(q₀) + ───────────────────────────── - ──────
#         2                                             2
#
#
# cos(q₀ + q₁)⋅u₁̇                   ⎛l₀⋅m₀⋅cos(q₀)      ⎛             l₁⋅cos(q₀
# ──────────────── - (m₀ + m₁)⋅u₃̇ - ⎜───────────── + m₁⋅⎜l₀⋅cos(q₀) + ─────────
#     2                              ⎝      2            ⎝                    2
#
#
#  + q₁)⎞⎞
# ──────⎟⎟⋅u₀̇
#       ⎠⎠

# %%
def multi_simp(kanezero):
    from multiprocessing import Pool

    p = Pool(7)
    kz = p.map(sym.trigsimp, kanezero)

# %%
com_vec = 1 / (m[0] + m[1]) * (m[0] * mc[0].pos_from(joints[0]) + m[1] * mc[1].pos_from(joints[0]))
com = joints[0].locatenew('com', com_vec)

# %%
com.pos_from(joints[2])
# Out:
# ⎛      l₀⋅m₀        ⎞
# ⎜      ───── + l₀⋅m₁⎟
# ⎜        2          ⎟
# ⎜-l₀ + ─────────────⎟
# ⎝         m₀ + m₁   ⎠ fr_0_x + ⎛      m₀⋅q₂ + m₁⋅q₂⎞
# ⎜-q₂ + ─────────────⎟
# ⎝         m₀ + m₁   ⎠ fr_n_x + ⎛      m₀⋅q₃ + m₁⋅q₃⎞
# ⎜-q₃ + ─────────────⎟
# ⎝         m₀ + m₁   ⎠ fr_n_y +    l₁⋅m₁
# ───────────
# 2⋅(m₀ + m₁) fr_1_x

# %%
com.v2pt_theory(joints[0], frames[0], frames[0])
# Out:
# 0

# %%
me.angular_momentum(com, frames[0], *bodies)
# Out:
# I_zz_0⋅u₀ fr_0_z + I_zz_1⋅(u₀ + u₁) fr_1_z

# %%
# actual snake values
masses = 40.5 * np.ones(n) / n / 1000  # kg
lengths = 68.6 * np.ones(n) / n / 100  # m
width = 2.2 / 100                      # m
mom_inertias = masses * (lengths**2 + width**2) / 12

constants = [g]
constants_vals = [9.81]
for i in range(n):
    constants = constants + [m[i], l[i], Izz[i]]
    constants_vals = constants_vals + [masses[i], lengths[i], mom_inertias[i]]

now = time.time()
mass_matrix = kane.mass_matrix_full
forcing_vector = kane.forcing_full
print('Equation rearranging:  {0:.3f} sec'.format(time.time() - now))

now = time.time()
right_hand_side = generate_ode_function(mass_matrix, forcing_vector, constants,
                                        q, u, T, generator='cython')
print('Code generation:       {0:.3f} sec'.format(time.time() - now))
# Out:
# Equation rearranging:  0.019 sec
# Code generation:       3.935 sec

# %%
def shape_space(x, t):
    trq = []
    for i in range(n + 1):
        trq.append(np.interp(t, ts, torques[:, i]))
    return np.array(trq)

# %%
# initial conditions
qstart = np.zeros(n + 2)
qstart[0] = np.pi/2
ustart = np.zeros(n + 2)
x0 = np.hstack((qstart, ustart))

npts = 501
ts, dt = linspace(0,  3, npts, retstep=True)

torques = np.zeros((npts, n + 1))
for i in range(n + 1):
    torques[:, i] = .005 * np.cos(10 * ts + np.pi/4 * i) * np.exp(-2 * ts)
    
args = {'constants': np.array(constants_vals),
        'specified': shape_space}

now = time.time()
y = odeint(right_hand_side, x0, ts, args=(args,))
print('Simulation time: {0:.2f} sec'.format(time.time() - now))
# Out:
# Simulation time: 1.36 sec

# %%
filename_prefix = 'multibody_system'
rhs = load_cython(filename_prefix, len(q), True)

# %%
fig, ax = plt.subplots()
ax.plot(ts, torques)
# Out:
# [<matplotlib.lines.Line2D at 0xf873490>,
#  <matplotlib.lines.Line2D at 0xf898b10>,
#  <matplotlib.lines.Line2D at 0xf898d50>,
#  <matplotlib.lines.Line2D at 0xf898f10>,
#  <matplotlib.lines.Line2D at 0xf89c110>,
#  <matplotlib.lines.Line2D at 0xf89c2d0>,
#  <matplotlib.lines.Line2D at 0xf89c490>]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
iq = n + 2

lines = ax1.plot(ts, y[:, :iq])
#lab = xlabel('Time [sec]')
leg = ax1.legend(q)

lines = ax2.plot(ts, y[:, iq:])
#lab = xlabel('Time [sec]')
leg = ax2.legend(u)

# %%
fig, ax = plt.subplots()
ax.plot(y[:, 1], y[:, 2])

# %%
def organize_data(y, n, ls, ms):
    """Organize the data so it can be animated with ellipses.
    """
    
    npts = y.shape[0]
    angs = y[:, :n]
    rads = angs.cumsum(axis=1)
    degs = np.rad2deg(rads)
    
    jtx, jty = y[:, n:n + 2].T
    jtx = jtx.reshape(-1, 1)
    jty = jty.reshape(-1, 1)
    
    mcx, mcy = [], []
    for i in range(n):
        dx = ls[i] * np.cos(rads[:, i])
        dy = ls[i] * np.sin(rads[:, i])
        
        mcx.append((jtx[:, i] + dx / 2).flatten())
        mcy.append((jty[:, i] + dy / 2).flatten())
        
        x = (jtx[:, i] + dx).reshape(-1, 1)
        y = (jty[:, i] + dy).reshape(-1, 1)
        
        jtx = np.hstack((jtx, x))
        jty = np.hstack((jty, y))
    
    mcx = np.array(mcx).T
    mcy = np.array(mcy).T
    
    # center of mass
    mms = np.array(ms)
    comx = (mcx * mms).sum(axis=1) / mms.sum()
    comy = (mcy * mms).sum(axis=1) / mms.sum()
     
    return rads, degs, jtx, jty, mcx, mcy, comx, comy


def n_movie_maker(n, lengths, ts, y, limx=(-1, 1), limy=(-1, 1)):
    
    rads, degs, jtx, jty, mcx, mcy, comx, comy = organize_data(y, n, lengths, masses)
    
    ws = .05 * lengths
    ws = width * np.ones(n)
    ii = 0
    st = 0
    hst = 50

    fig, ax = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(9, 9))
    ax.axis('image')
    ax.set_xlim(limx)
    ax.set_ylim(limy)

    fig.set_facecolor('w')
    fig.tight_layout()

    time_fmt = '{0:2.3} sec'
    time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes, fontsize='large')

    ellipse_params = dict(alpha=.5, edgecolor='None', color='green')
    patches = []
    for i in range(n):
        e = Ellipse(xy=(mcx[ii, i], mcy[ii, i]),
                    width=ws[i], height=1.05 * lengths[i],
                    angle=degs[ii, i] - 90, **ellipse_params)
        ax.add_patch(e)
        patches.append(e)
        
    head, = ax.plot(jtx[ii, 0], jty[ii, 0], 'go', alpha=.6, markersize=7)
    jlines, mclines = [], []
    for i in range(n):
        jline, = ax.plot(jtx[st:ii, i + 1], jty[st:ii, i + 1], 'b--', alpha=.5)
        mcline, = ax.plot(mcx[st:ii, i], mcy[st:ii, i], 'r', alpha=.5)
        jlines.append(jline)
        mclines.append(mcline)

    coml, = ax.plot(comx[st:ii], comy[st:ii], 'k-', lw=2, alpha=.9)
    
    def init():
        ii = 0
        head.set_data(jtx[ii, 0], jty[ii, 0])
        for i in range(n):
            patches[i].set_alpha(.3)
        time_text.set_text('')
        return [head, time_text] + patches

    def animate(ii):

        st = ii - hst
        if st < 0:
            st = 0
        
        head.set_data(jtx[ii, 0], jty[ii, 0])
        for i in range(n):
            patches[i].set_visible(True)
            patches[i].set_alpha(.5)
            patches[i].center = (mcx[ii, i], mcy[ii, i])
            patches[i].angle = degs[ii, i] - 90
            jlines[i].set_data(jtx[st:ii, i + 1], jty[st:ii, i + 1])
            mclines[i].set_data(mcx[st:ii, i], mcy[st:ii, i])
        
        time_text.set_text(time_fmt.format(ts[ii]))

        coml.set_data(comx[st:ii], comy[st:ii])

        return patches + [head, coml, time_text] + jlines + mclines

    anim = animation.FuncAnimation(fig, animate, frames=len(ts),
                interval=ts[-1] / len(ts) * 1000, blit=True, repeat=False, init_func=init)
    
    return anim
    
n_movie_maker(n, lengths, ts, y)

# %%
rads, degs, jtx, jty, mcx, mcy, comx, comy = organize_data(y, n, lengths, masses)

# %%
plt.close('all')

# %%
animation.FuncAnimation??

# %%
mcx.shape
# Out:
# (501, 5)

# %%
jtx.shape
# Out:
# (501, 6)

# %%
jtx.shape
# Out:
# (501, 6)

# %%
def shape_space(x, t):
    
    torques = []
    for i in range(1, n - 1):
        torques.append(i)
    torques = [0] + torques + [0]
    #tk1 = np.interp(t, ts, t1)
    #tk2 = np.interp(t, ts, t2)

    return np.array(torques)

args = {'constants': np.array(constant_vals),
        'specified': shape_space}

qstart = np.pi/2
ustart = (.3, 0.0, .0, 0, 0)
#ustart = np.zeros(5)
x0 = np.hstack((qstart, ustart))

npts = 1001
ts, dt = linspace(0,  10, npts, retstep=True)

# t1 = 60 * np.ones(npts)
# t2 = -30 * np.ones(npts)

t1 = .025 * np.cos(10 * ts)
t2 = -.025 * np.cos(10 * ts + np.pi/4)

# t1 *= 0
# t2 *= 0

# t1[t1 > 0] = t1.max()
# t2[tt2 > 0] = t2.max()

# t1[theta1 < 0] = t1.min()
# t2[theta2 < 0] = t2.min()

now = time.time()
y1 = odeint(right_hand_side, x0, ts, args=(args,))
y1 = y1.T
print('Elapsed time: {0:.2f} sec'.format(time.time() - now))

# organize the data
th0, th1, th2 = y1[:3]
th1 = th1 + th0
th2 = th2 + th1

dg0, dg1, dg2 = np.rad2deg(y1[:3])
dg1 = dg1 + dg0
dg2 = dg2 + dg1

j0 = np.c_[0, 0]
j0 = y1[3:5].T
j1 = j0 + np.c_[ls   * np.cos(th0), ls   * np.sin(th0)]
j2 = j1 + np.c_[ls   * np.cos(th1), ls   * np.sin(th1)]
j3 = j2 + np.c_[ls   * np.cos(th2), ls   * np.sin(th2)]
c0 = j0 + np.c_[ls/2 * np.cos(th0), ls/2 * np.sin(th0)]
c1 = j1 + np.c_[ls/2 * np.cos(th1), ls/2 * np.sin(th1)]
c2 = j2 + np.c_[ls/2 * np.cos(th2), ls/2 * np.sin(th2)]

# center of mass
mms = np.array([ms, ms, ms])
cx = np.c_[c0[:, 0], c1[:, 0], c2[:, 0]]
cy = np.c_[c0[:, 1], c1[:, 1], c2[:, 1]]
com = np.c_[(cx * mms).sum(axis=1), (cy * mms).sum(axis=1)] / mms.sum()

# %%
# number of links (not currently used)
n = 3

# dynamic variables
q0, q1, q2 = me.dynamicsymbols('q0 q1 q2')
u0, u1, u2 = me.dynamicsymbols('u0 u1 u2')

# location of the head
q3, q4 = me.dynamicsymbols('q3 q4')
u3, u4 = me.dynamicsymbols('u3 u4')

# time varying torques
T0, T1, T2, T3 = sym.symbols('T_0 T_1 T_2 T_3')

# variables for bodies
g, t = sym.symbols('g t')
m0, m1, m2 = sym.symbols('m_0 m_1 m_2')
l0, l1, l2 = sym.symbols('l_0 l_1 l_2')
Izz0, Izz1, Izz2 = sym.symbols('I_zz_0 I_zz_1 I_zz_2')

# inertial reference frame
frN = me.ReferenceFrame('fr_N')

# body-fixed frames
fr0 = frN.orientnew('fr_0', 'Axis', [q0, frN.z])
fr1 = fr0.orientnew('fr_1', 'Axis', [q1, fr0.z])
fr2 = fr1.orientnew('fr_2', 'Axis', [q2, fr1.z])

# angular velocities of frames
fr0.set_ang_vel(frN, u0 * frN.z)
fr1.set_ang_vel(fr0, u1 * fr0.z)
fr2.set_ang_vel(fr1, u2 * fr1.z)

# origin of inertial frame
Nor = me.Point('N_or')

# joints
jt0 = Nor.locatenew('jt_0', q3 * frN.x + q4 * frN.y)
jt1 = jt0.locatenew('jt_1', l0 * fr0.x)
jt2 = jt1.locatenew('jt_2', l1 * fr1.x)
jt3 = jt2.locatenew('jt_3', l2 * fr2.x)

# mass centers
mc0 = jt0.locatenew('mc_0', l0 / 2 * fr0.x)
mc1 = jt1.locatenew('mc_1', l1 / 2 * fr1.x)
mc2 = jt2.locatenew('mc_2', l2 / 2 * fr2.x)

# constrained point velocities
Nor.set_vel(frN, 0)
jt0.set_vel(frN, u3 * frN.x + u4 * frN.y)

# unconstrained point velocities
jt1.v2pt_theory(jt0, frN, fr0)
jt2.v2pt_theory(jt1, frN, fr1)
jt3.v2pt_theory(jt2, frN, fr2)

mc0.v2pt_theory(jt0, frN, fr0)
mc1.v2pt_theory(jt1, frN, fr1)
mc2.v2pt_theory(jt2, frN, fr2)

# inertia dyads
in0 = (me.inertia(fr0, 0, 0, Izz0), mc0)
in1 = (me.inertia(fr1, 0, 0, Izz1), mc1)
in2 = (me.inertia(fr2, 0, 0, Izz2), mc2)

# bodies
bd0 = me.RigidBody('bd_0', mc0, fr0, m0, in0)
bd1 = me.RigidBody('bd_1', mc1, fr1, m1, in1)
bd2 = me.RigidBody('bd_2', mc2, fr2, m2, in2)

# kinematic differential equations
kd = [q0.diff(t) - u0,
      q1.diff(t) - u1,
      q2.diff(t) - u2,
      q3.diff(t) - u3,
      q4.diff(t) - u4]

# forces and toques
fl = [(mc0, -m0 * g * frN.z),
      (mc1, -m1 * g * frN.z),
      (mc2, -m2 * g * frN.z),
      (fr0, (T0 - T1) * frN.z),
      (fr1, (T1 - T2) * frN.z),
      (fr2, (T2 - T3) * frN.z)]

# bodies
bl = [bd0, bd1, bd2]

# q_ind and u_ind
coords = [q0, q1, q2, q3, q4]
speeds = [u0, u1, u2, u3, u4]


# equations of motion using Kane's method
kane = me.KanesMethod(frame=frN,
                      q_ind=coords,
                      u_ind=speeds,
                      kd_eqs=kd,
                      q_dependent=[],
                      configuration_constraints=[],
                      u_dependent=[],
                      velocity_constraints=[])

(fr, frstar) = kane.kanes_equations(fl, bl)
kanezero = fr + frstar

# these take to long...
# solve Kane's equations for the derivatives of the speeds
#eom = sym.solvers.solve(kanezero, q0d, q1d, q2d)

# add the kinematical differential equations to get the equations of motion
#eom.update(kane.kindiffdict())

# print the results
#me.mprint(eom)

#rhs = kane.mass_matrix.inv() * kane.forcing
#me.mprint(rhs)

#j3pos = jt3.pos_from(jt0).express(frN).simplify()
#sym.trigsimp(kanezero)

# %%
kz = sym.trigsimp(kanezero)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-266b1087eba3> in <module>()
# ----> 1 kz = sym.trigsimp(kanezero)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in trigsimp(expr, **opts)
#    1430                    }[method]
#    1431
# -> 1432     return trigsimpfunc(expr)
#    1433
#    1434
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in <lambda>(x)
#    1423     trigsimpfunc = {
#    1424         'fu': (lambda x: fu(x, **opts)),
# -> 1425         'matching': (lambda x: futrig(x)),
#    1426         'groebner': (lambda x: groebnersimp(x, **opts)),
#    1427         'combined': (lambda x: futrig(groebnersimp(x,
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in futrig(e, **kwargs)
#    4282
#    4283     old = e
# -> 4284     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    4285
#    4286     if kwargs.pop('hyper', True) and e.has(C.HyperbolicFunction):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4054         if rv.args:
#    4055             args = tuple([bottom_up(a, F, atoms, nonbasic)
# -> 4056                 for a in rv.args])
#    4057             if args != rv.args:
#    4058                 rv = rv.func(*args)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4054         if rv.args:
#    4055             args = tuple([bottom_up(a, F, atoms, nonbasic)
# -> 4056                 for a in rv.args])
#    4057             if args != rv.args:
#    4058                 rv = rv.func(*args)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4057             if args != rv.args:
#    4058                 rv = rv.func(*args)
# -> 4059             rv = F(rv)
#    4060         elif atoms:
#    4061             rv = F(rv)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in <lambda>(x)
#    4282
#    4283     old = e
# -> 4284     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    4285
#    4286     if kwargs.pop('hyper', True) and e.has(C.HyperbolicFunction):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in _futrig(e, **kwargs)
#    4352             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    4353         )]
# -> 4354     e = greedy(tree, objective=Lops)(e)
#    4355
#    4356     return coeff*e
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/strategies/core.pyc in minrule(expr)
#     116     objective = kwargs.get('objective', identity)
#     117     def minrule(expr):
# --> 118         return min([rule(expr) for rule in rules], key=objective)
#     119     return minrule
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/strategies/core.pyc in chain_rl(expr)
#      43     def chain_rl(expr):
#      44         for rule in rules:
# ---> 45             expr = rule(expr)
#      46         return expr
#      47     return chain_rl
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in <lambda>(x)
#    4329         TR10,  # sin-cos of sums -> sin-cos prod
#    4330         TR11, TR6, # reduce double angles and rewrite cos pows
# -> 4331         lambda x: _eapply(factor, x, trigs),
#    4332         TR14,  # factored powers of identities
#    4333         [identity, lambda x: _eapply(_mexpand, x, trigs)],
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in _eapply(func, e, cond)
#    4245         return e
#    4246     if _is_Expr(e) or not e.args:
# -> 4247         return func(e)
#    4248     return e.func(*[
#    4249         _eapply(func, ei) if (cond is None or cond(ei)) else ei
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/polytools.pyc in factor(f, *gens, **args)
#    5939
#    5940     try:
# -> 5941         return _generic_factor(f, gens, args, method='factor')
#    5942     except PolynomialError as msg:
#    5943         if not f.is_commutative:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/polytools.pyc in _generic_factor(expr, gens, args, method)
#    5634     options.allowed_flags(args, [])
#    5635     opt = options.build_options(gens, args)
# -> 5636     return _symbolic_factor(sympify(expr), opt, method)
#    5637
#    5638
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/polytools.pyc in _symbolic_factor(expr, opt, method)
#    5579         if hasattr(expr,'_eval_factor'):
#    5580             return expr._eval_factor()
# -> 5581         coeff, factors = _symbolic_factor_list(together(expr), opt, method)
#    5582         return _keep_coeff(coeff, _factors_product(factors))
#    5583     elif hasattr(expr, 'args'):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/polytools.pyc in _symbolic_factor_list(expr, opt, method)
#    5543             func = getattr(poly, method + '_list')
#    5544
# -> 5545             _coeff, _factors = func()
#    5546             if _coeff is not S.One:
#    5547                 if exp.is_Integer:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/polytools.pyc in factor_list(f)
#    3057         if hasattr(f.rep, 'factor_list'):
#    3058             try:
# -> 3059                 coeff, factors = f.rep.factor_list()
#    3060             except DomainError:
#    3061                 return S.One, [(f, 1)]
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/polyclasses.pyc in factor_list(f)
#     757     def factor_list(f):
#     758         """Returns a list of irreducible factors of ``f``. """
# --> 759         coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     760         return coeff, [ (f.per(g), k) for g, k in factors ]
#     761
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/factortools.pyc in dmp_factor_list(f, u, K0)
#    1277         if K.is_ZZ:
#    1278             levels, f, v = dmp_exclude(f, u, K)
# -> 1279             coeff, factors = dmp_zz_factor(f, v, K)
#    1280
#    1281             for i, (f, k) in enumerate(factors):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/factortools.pyc in dmp_zz_factor(f, u, K)
#    1088
#    1089     if dmp_degree(g, u) > 0:
# -> 1090         g = dmp_sqf_part(g, u, K)
#    1091         H = dmp_zz_wang(g, u, K)
#    1092         factors = dmp_trial_division(f, H, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/sqfreetools.pyc in dmp_sqf_part(f, u, K)
#     245         f = dmp_neg(f, u, K)
#     246
# --> 247     gcd = dmp_gcd(f, dmp_diff(f, 1, u, K), u, K)
#     248     sqf = dmp_quo(f, gcd, u, K)
#     249
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     996             G = dmp_content(g, u, K)
#     997         else:
# --> 998             F = dmp_content(f, u, K)
#     999             G = dmp_LC(g, K)
#    1000
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     994         if not df:
#     995             F = dmp_LC(f, K)
# --> 996             G = dmp_content(g, u, K)
#     997         else:
#     998             F = dmp_content(f, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     994         if not df:
#     995             F = dmp_LC(f, K)
# --> 996             G = dmp_content(g, u, K)
#     997         else:
#     998             F = dmp_content(f, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     994         if not df:
#     995             F = dmp_LC(f, K)
# --> 996             G = dmp_content(g, u, K)
#     997         else:
#     998             F = dmp_content(f, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     994         if not df:
#     995             F = dmp_LC(f, K)
# --> 996             G = dmp_content(g, u, K)
#     997         else:
#     998             F = dmp_content(f, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#    1000
#    1001     v = u - 1
# -> 1002     h = dmp_gcd(F, G, v, K)
#    1003
#    1004     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#    1000
#    1001     v = u - 1
# -> 1002     h = dmp_gcd(F, G, v, K)
#    1003
#    1004     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     994         if not df:
#     995             F = dmp_LC(f, K)
# --> 996             G = dmp_content(g, u, K)
#     997         else:
#     998             F = dmp_content(f, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     994         if not df:
#     995             F = dmp_LC(f, K)
# --> 996             G = dmp_content(g, u, K)
#     997         else:
#     998             F = dmp_content(f, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#    1000
#    1001     v = u - 1
# -> 1002     h = dmp_gcd(F, G, v, K)
#    1003
#    1004     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     994         if not df:
#     995             F = dmp_LC(f, K)
# --> 996             G = dmp_content(g, u, K)
#     997         else:
#     998             F = dmp_content(f, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     994         if not df:
#     995             F = dmp_LC(f, K)
# --> 996             G = dmp_content(g, u, K)
#     997         else:
#     998             F = dmp_content(f, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1377
#    1378         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1379             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1380
#    1381             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#    1000
#    1001     v = u - 1
# -> 1002     h = dmp_gcd(F, G, v, K)
#    1003
#    1004     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1377
#    1378         if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1379             h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1380
#    1381             h = _dmp_zz_gcd_interpolate(h, x, v, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#     994         if not df:
#     995             F = dmp_LC(f, K)
# --> 996             G = dmp_content(g, u, K)
#     997         else:
#     998             F = dmp_content(f, u, K)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_content(f, u, K)
#    1836
#    1837     for c in f[1:]:
# -> 1838         cont = dmp_gcd(cont, c, v, K)
#    1839
#    1840         if dmp_one_p(cont, v, K):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#    1000
#    1001     v = u - 1
# -> 1002     h = dmp_gcd(F, G, v, K)
#    1003
#    1004     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1354         return dup_zz_heu_gcd(f, g, K)
#    1355
# -> 1356     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1357
#    1358     if result is not None:
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_rr_trivial_gcd(f, g, u, K)
#     954             return dmp_neg(f, u, K), dmp_ground(-K.one, u), dmp_zero(u)
#     955     elif query('USE_SIMPLIFY_GCD'):
# --> 956         return _dmp_simplify_gcd(f, g, u, K)
#     957     else:
#     958         return None
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_simplify_gcd(f, g, u, K)
#    1000
#    1001     v = u - 1
# -> 1002     h = dmp_gcd(F, G, v, K)
#    1003
#    1004     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_gcd(f, g, u, K)
#    1668
#    1669     """
# -> 1670     return dmp_inner_gcd(f, g, u, K)[0]
#    1671
#    1672
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_inner_gcd(f, g, u, K)
#    1627
#    1628     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1629     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1630
#    1631     return (dmp_inflate(h, J, u, K),
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in _dmp_inner_gcd(f, g, u, K)
#    1596         if K.is_ZZ and query('USE_HEU_GCD'):
#    1597             try:
# -> 1598                 return dmp_zz_heu_gcd(f, g, u, K)
#    1599             except HeuristicGCDFailed:
#    1600                 pass
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/euclidtools.pyc in dmp_zz_heu_gcd(f, g, u, K)
#    1382             h = dmp_ground_primitive(h, u, K)[1]
#    1383
# -> 1384             cff_, r = dmp_div(f, h, u, K)
#    1385
#    1386             if dmp_zero_p(r, u):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/densearith.pyc in dmp_div(f, g, u, K)
#    1625         return dmp_ff_div(f, g, u, K)
#    1626     else:
# -> 1627         return dmp_rr_div(f, g, u, K)
#    1628
#    1629
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/densearith.pyc in dmp_rr_div(f, g, u, K)
#    1391     while True:
#    1392         lc_r = dmp_LC(r, K)
# -> 1393         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1394
#    1395         if not dmp_zero_p(R, v):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/densearith.pyc in dmp_rr_div(f, g, u, K)
#    1391     while True:
#    1392         lc_r = dmp_LC(r, K)
# -> 1393         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1394
#    1395         if not dmp_zero_p(R, v):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/densearith.pyc in dmp_rr_div(f, g, u, K)
#    1391     while True:
#    1392         lc_r = dmp_LC(r, K)
# -> 1393         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1394
#    1395         if not dmp_zero_p(R, v):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/densearith.pyc in dmp_rr_div(f, g, u, K)
#    1391     while True:
#    1392         lc_r = dmp_LC(r, K)
# -> 1393         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1394
#    1395         if not dmp_zero_p(R, v):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/densearith.pyc in dmp_rr_div(f, g, u, K)
#    1374     """
#    1375     if not u:
# -> 1376         return dup_rr_div(f, g, K)
#    1377
#    1378     df = dmp_degree(f, u)
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/polys/densearith.pyc in dup_rr_div(f, g, K)
#    1351         _dr, dr = dr, dup_degree(r)
#    1352
# -> 1353         if dr < dg:
#    1354             break
#    1355         elif not (dr < _dr):
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/core/decorators.pyc in __sympifyit_wrapper(a, b)
#      75                 if not hasattr(b, '_op_priority'):
#      76                     b = sympify(b, strict=True)
# ---> 77                 return func(a, b)
#      78             except SympifyError:
#      79                 return retval
#
# /home/isaac/anaconda/lib/python2.7/site-packages/sympy/core/numbers.pyc in __lt__(self, other)
#    2434         if other.is_number and other.is_real is False:
#    2435             raise TypeError("Invalid comparison of %s and %s" % (self, other))
# -> 2436         return other is not S.NegativeInfinity
#    2437
#    2438     @_sympifyit('other', NotImplemented)
#
# KeyboardInterrupt:

# %%
sym.trigsimp(kanezero[1])
# Out:
#                      2                                             2
#           l₀⋅l₁⋅m₁⋅u₀ ⋅sin(q₁)              2           l₀⋅l₂⋅m₂⋅u₀ ⋅sin(q₁ +
# T₁ - T₃ - ──────────────────── - l₀⋅l₁⋅m₂⋅u₀ ⋅sin(q₁) - ──────────────────────
#                    2                                                2
#
#                         2                                  2
# q₂)   l₁⋅l₂⋅m₂⋅(u₀ + u₁) ⋅sin(q₂)   l₁⋅l₂⋅m₂⋅(u₀ + u₁ + u₂) ⋅sin(q₂)   ⎛
# ─── - ─────────────────────────── + ──────────────────────────────── - ⎜I_zz_2
#                    2                               2                   ⎝
#
#
#    l₂⋅m₂⋅(2⋅l₁⋅cos(q₂) + l₂)⎞       ⎛  l₁⋅m₁⋅sin(q₀ + q₁)      ⎛
#  + ─────────────────────────⎟⋅u₂̇ - ⎜- ────────────────── + m₂⋅⎜-l₁⋅sin(q₀ + q
#                4            ⎠       ⎝          2               ⎝
#
#
#      l₂⋅sin(q₀ + q₁ + q₂)⎞⎞       ⎛l₁⋅m₁⋅cos(q₀ + q₁)      ⎛
# ₁) - ────────────────────⎟⎟⋅u₃̇ - ⎜────────────────── + m₂⋅⎜l₁⋅cos(q₀ + q₁) +
#               2          ⎠⎠       ⎝        2               ⎝
#
#                              ⎛                    2         ⎛
# l₂⋅cos(q₀ + q₁ + q₂)⎞⎞       ⎜                  l₁ ⋅m₁      ⎜  2
# ────────────────────⎟⎟⋅u₄̇ - ⎜I_zz_1 + I_zz_2 + ────── + m₂⋅⎜l₁  + l₁⋅l₂⋅cos(q
#          2          ⎠⎠       ⎝                    4         ⎝
#
#        2⎞⎞       ⎛                                                 ⎛
#      l₂ ⎟⎟       ⎜                  l₁⋅m₁⋅(2⋅l₀⋅cos(q₁) + l₁)      ⎜
# ₂) + ───⎟⎟⋅u₁̇ - ⎜I_zz_1 + I_zz_2 + ───────────────────────── + m₂⋅⎜l₀⋅l₁⋅cos(
#       4 ⎠⎠       ⎝                              4                  ⎝
#
#                                                    2⎞⎞
#       l₀⋅l₂⋅cos(q₁ + q₂)     2                   l₂ ⎟⎟
# q₁) + ────────────────── + l₁  + l₁⋅l₂⋅cos(q₂) + ───⎟⎟⋅u₀̇
#               2                                   4 ⎠⎠

# %%
kz[4]
# Out:
#         2                                                                  2
# l₀⋅m₀⋅u₀ ⋅sin(q₀)           2                   2           l₁⋅m₁⋅(u₀ + u₁) ⋅s
# ───────────────── + l₀⋅m₁⋅u₀ ⋅sin(q₀) + l₀⋅m₂⋅u₀ ⋅sin(q₀) + ──────────────────
#         2                                                                 2
#
#                                                                   2
# in(q₀ + q₁)                  2                l₂⋅m₂⋅(u₀ + u₁ + u₂) ⋅sin(q₀ + q
# ─────────── + l₁⋅m₂⋅(u₀ + u₁) ⋅sin(q₀ + q₁) + ────────────────────────────────
#                                                                  2
#
#
# ₁ + q₂)   l₂⋅m₂⋅cos(q₀ + q₁ + q₂)⋅u₂̇   ⎛l₁⋅m₁⋅cos(q₀ + q₁)      ⎛
# ─────── - ─────────────────────────── - ⎜────────────────── + m₂⋅⎜l₁⋅cos(q₀ +
#                        2                ⎝        2               ⎝
#
#
#       l₂⋅cos(q₀ + q₁ + q₂)⎞⎞                            ⎛l₀⋅m₀⋅cos(q₀)      ⎛
# q₁) + ────────────────────⎟⎟⋅u₁̇ - (m₀ + m₁ + m₂)⋅u₄̇ - ⎜───────────── + m₁⋅⎜l
#                2          ⎠⎠                            ⎝      2            ⎝
#
#
#             l₁⋅cos(q₀ + q₁)⎞      ⎛                               l₂⋅cos(q₀ +
# ₀⋅cos(q₀) + ───────────────⎟ + m₂⋅⎜l₀⋅cos(q₀) + l₁⋅cos(q₀ + q₁) + ────────────
#                    2       ⎠      ⎝                                        2
#
#
# q₁ + q₂)⎞⎞
# ────────⎟⎟⋅u₀̇
#         ⎠⎠

# %%
from pydy_code_gen.code import generate_ode_function

# parameter values
ls = .25                          # segment lengths
ms = .15                          # segment masses
ws_ratio = .1                     # width is a function of length
ws = ls * ws_ratio                # segment widths
Izzs = ms * (ls**2 + ws**2) / 12  # flat plate about com

coords = [q0, q1, q2, q3, q4]
speeds = [u0, u1, u2, u3, u4]
constants = [g, m0, l0, Izz0, m1, l1, Izz1, m2, l2, Izz2]
constant_vals = [9.81, ms, ls, Izzs, ms, ls, Izzs, ms, ls, Izzs]
specified = [T0, T1, T2, T3]
mass_matrix = kane.mass_matrix_full
forcing_vector = kane.forcing_full

right_hand_side = generate_ode_function(mass_matrix, forcing_vector, constants,
                                        coords, speeds, specified, generator='cython')

# %%
def shape_space(x, t):
    
    tk1 = np.interp(t, ts, t1)
    tk2 = np.interp(t, ts, t2)

    return np.r_[0, tk1, tk2, 0]

args = {'constants': np.array(constant_vals),
        'specified': shape_space}

qstart = (0, 0, 0, 0, 0)
ustart = (.3, 0.0, .0, 0, 0)
#ustart = np.zeros(5)
x0 = np.hstack((qstart, ustart))

npts = 1001
ts, dt = linspace(0,  10, npts, retstep=True)

# t1 = 60 * np.ones(npts)
# t2 = -30 * np.ones(npts)

t1 = .025 * np.cos(10 * ts)
t2 = -.025 * np.cos(10 * ts + np.pi/4)

# t1 *= 0
# t2 *= 0

# t1[t1 > 0] = t1.max()
# t2[tt2 > 0] = t2.max()

# t1[theta1 < 0] = t1.min()
# t2[theta2 < 0] = t2.min()

now = time.time()
y1 = odeint(right_hand_side, x0, ts, args=(args,))
y1 = y1.T
print('Elapsed time: {0:.2f} sec'.format(time.time() - now))

# organize the data
th0, th1, th2 = y1[:3]
th1 = th1 + th0
th2 = th2 + th1

dg0, dg1, dg2 = np.rad2deg(y1[:3])
dg1 = dg1 + dg0
dg2 = dg2 + dg1

j0 = np.c_[0, 0]
j0 = y1[3:5].T
j1 = j0 + np.c_[ls   * np.cos(th0), ls   * np.sin(th0)]
j2 = j1 + np.c_[ls   * np.cos(th1), ls   * np.sin(th1)]
j3 = j2 + np.c_[ls   * np.cos(th2), ls   * np.sin(th2)]
c0 = j0 + np.c_[ls/2 * np.cos(th0), ls/2 * np.sin(th0)]
c1 = j1 + np.c_[ls/2 * np.cos(th1), ls/2 * np.sin(th1)]
c2 = j2 + np.c_[ls/2 * np.cos(th2), ls/2 * np.sin(th2)]

# center of mass
mms = np.array([ms, ms, ms])
cx = np.c_[c0[:, 0], c1[:, 0], c2[:, 0]]
cy = np.c_[c0[:, 1], c1[:, 1], c2[:, 1]]
com = np.c_[(cx * mms).sum(axis=1), (cy * mms).sum(axis=1)] / mms.sum()
# Out:
# Elapsed time: 6.19 sec

# %%
fig, ax = plt.subplots()
ax.plot(ts, t1)
ax.plot(ts, t2)

fig, ax = plt.subplots()
ax.plot(np.rad2deg(y1[1]), np.rad2deg(y1[2]))

# %%
plt.close('all')

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(6, 6))

ax1.plot(y1[0])
ax1.plot(y1[1])
ax1.plot(y1[2])

ax2.plot(y1[5])
ax2.plot(y1[6])
ax2.plot(y1[7])

ax2.set_xlabel('iteration')
ax1.set_ylabel('q', rotation='horizontal')
ax2.set_ylabel('u', rotation='horizontal')

fig.tight_layout()

#display(fig)

# %%
#%matplotlib inline

def movie_maker():
    
    ii = 0
    st = 0
    hst = 250

    fig, ax = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(9, 9))

    ax.axis('image')
    ax.set_xlim(-1, 1)
    ax.set_ylim(-1, 1)

    fig.set_facecolor('w')
    fig.tight_layout()

    time_text = ax.text(0.05, 0.9, '{0:.3} sec'.format(ts[ii]), transform=ax.transAxes)

    ellipse_params = dict(alpha=.5, edgecolor='None', color='green')
    e0 = Ellipse(xy=c0[ii], width=ws, height=1.05 * ls, angle=dg0[ii] - 90, **ellipse_params)
    e1 = Ellipse(xy=c1[ii], width=ws, height=1.05 * ls, angle=dg1[ii] - 90, **ellipse_params)
    e2 = Ellipse(xy=c2[ii], width=ws, height=1.05 * ls, angle=dg2[ii] - 90, **ellipse_params)
    patches = [e0, e1, e2]
    map(ax.add_patch, patches)

    j0l, = ax.plot(j0[ii, 0], j0[ii, 1], 'go', alpha=.6, markersize=7)
    j1l, = ax.plot(j1[st:ii, 0], j1[st:ii, 1], 'b--')
    j2l, = ax.plot(j2[st:ii, 0], j2[st:ii, 1], 'g--')
    j3l, = ax.plot(j3[st:ii, 0], j3[st:ii, 1], 'r--')

    c0l, = ax.plot(c0[st:ii, 0], c0[st:ii, 1], 'b')
    c1l, = ax.plot(c1[st:ii, 0], c1[st:ii, 1], 'g')
    c2l, = ax.plot(c2[st:ii, 0], c2[st:ii, 1], 'r')

    coml, = ax.plot(com[st:ii, 0], com[st:ii, 1], 'k-', lw=2, alpha=.9)

    def animate(ii):

        st = ii - hst
        if st < 0:
            st = 0

        e0.center = c0[ii]
        e0.angle = dg0[ii] - 90

        e1.center = c1[ii]
        e1.angle = dg1[ii] - 90

        e2.center = c2[ii]
        e2.angle = dg2[ii] - 90

        j0l.set_data(j0[ii, 0], j0[ii, 1])
        j1l.set_data(j1[st:ii, 0], j1[st:ii, 1])
        j2l.set_data(j2[st:ii, 0], j2[st:ii, 1])
        j3l.set_data(j3[st:ii, 0], j3[st:ii, 1])

        c0l.set_data(c0[st:ii, 0], c0[st:ii, 1])
        c1l.set_data(c1[st:ii, 0], c1[st:ii, 1])
        c2l.set_data(c2[st:ii, 0], c2[st:ii, 1])

        coml.set_data(com[st:ii, 0], com[st:ii, 1])

        return e0, e1, e2, j0l, j1l, j2l, j3l, c0l, c1l, c2l

    anim = animation.FuncAnimation(fig, animate, frames=len(ts),
                interval=ts[-1] / len(ts) * 1000, blit=True, repeat=False)
    
    return anim
    
movie_maker()

# %%
plt.close('all')

# %%
fig, ax = plt.subplots()

ax.plot(j0[:, 0], j0[:, 1], 'r')
ax.plot(j3[:, 0], j3[:, 1], 'g')
ax.plot(com[:, 0], com[:, 1], 'k')

# %%
sym.angular_momentum?
# Out:
# Object `sym.angular_momentum` not found.

# %%
M = 3 * ms
1 / M * np.sum()
# Out:
# 0.45

# %%
fig, ax = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(6, 6))
    
fig.tight_layout()

# display the current time
time_text = ax.text(0.05, 0.9, 'time here', transform=ax.transAxes)

# create a rectangular cart
ell = [Ellipse(xy=(0, 0), width=.05*ls, height=1.05 * ls, angle=100 * np.random.random(),
                    alpha=.5, edgecolor='None', color='green')
            for i in range(n)]
[ax.add_patch(ellis) for ellis in ell]

lim = 3 * ls
ax.set_xlim(-lim, lim)
ax.set_ylim(-lim, lim)

th0, th1, th2 = y1[:3]
dg0, dg1, dg2 = np.rad2deg(y1[:3])

j0 = np.c_[0, 0]
c0 = j0 + np.c_[ls/2 * np.cos(th0), ls/2 * np.sin(th0)]

j1 = j0 + np.c_[ls   * np.cos(th0), ls   * np.sin(th0)]
c1 = j1 + np.c_[ls/2 * np.cos(th1), ls/2 * np.sin(th1)]

j2 = j1 + np.c_[ls   * np.cos(th1), ls   * np.sin(th1)]
c2 = j2 + np.c_[ls/2 * np.cos(th2), ls/2 * np.sin(th2)]

j3 = j2 + np.c_[ls   * np.cos(th2), ls   * np.sin(th2)]


ii = 100

ell[0].center = c0[ii]
ell[1].center = c1[ii]
ell[2].center = c2[ii]

ell[0].angle = dg0[ii] - 90
ell[1].angle = dg1[ii] - 90
ell[2].angle = dg2[ii] - 90

ax.axis('image')
ax.set_xlim(-.7, .7)
ax.set_ylim(-.7, .7)

ax.plot(j1[:ii, 0], j1[:ii, 1], 'b--')
ax.plot(j2[:ii, 0], j2[:ii, 1], 'g--')
ax.plot(j3[:ii, 0], j3[:ii, 1], 'r--')

ax.plot(c0[:ii, 0], c0[:ii, 1], 'b')
ax.plot(c1[:ii, 0], c1[:ii, 1], 'g')
ax.plot(c2[:ii, 0], c2[:ii, 1], 'r')

# %%
-dg2[:20] + 90
# Out:
# array([ 0.        , -0.05208   , -0.09370436, -0.12483333, -0.14542379,
#        -0.15542785, -0.15479371, -0.14346486, -0.12138054, -0.08847643,
#        -0.0446831 ,  0.01007321,  0.0758705 ,  0.15279123,  0.24092226,
#         0.34035504,  0.45118562,  0.5735147 ,  0.70744765,  0.85309458])

# %%
fig, ax = plt.subplots(figsize=(7, 7))
ax.plot(j3[:, 0], j3[:, 1], alpha=.4)
ax.plot(j2[:, 0], j2[:, 1], alpha=.7)
ax.plot(j1[:, 0], j1[:, 1], alpha=.7)
ax.plot(j0[:, 0], j0[:, 1], alpha=.7)

ax.axis('equal')

fig.tight_layout()

# %%
    # the number of pendulum bobs
    numpoints = states.shape[1] / 2

    # first set up the figure, the axis, and the plot elements we want to animate
    fig = plt.figure()
    
    # some dimesions
    cart_width = 0.4
    cart_height = 0.2
    
    # set the limits based on the motion
    xmin = around(states[:, 0].min() - cart_width / 2.0, 1)
    xmax = around(states[:, 0].max() + cart_width / 2.0, 1)
    
    # create the axes
    ax = plt.axes(xlim=(xmin, xmax), ylim=(-1.1, 1.1), aspect='equal')
    
    # display the current time
    time_text = ax.text(0.04, 0.9, '', transform=ax.transAxes)
    
    # create a rectangular cart
    rect = Rectangle([states[0, 0] - cart_width / 2.0, -cart_height / 2],
        cart_width, cart_height, fill=True, color='red', ec='black')
    ax.add_patch(rect)
    
    # blank line for the pendulum
    line, = ax.plot([], [], lw=2, marker='o', markersize=6)

    # initialization function: plot the background of each frame
    def init():
        time_text.set_text('')
        rect.set_xy((0.0, 0.0))
        line.set_data([], [])
        return time_text, rect, line,

    # animation function: update the objects
    def animate(i):
        time_text.set_text('time = {:2.2f}'.format(t[i]))
        rect.set_xy((states[i, 0] - cart_width / 2.0, -cart_height / 2))
        x = hstack((states[i, 0], zeros((numpoints - 1))))
        y = zeros((numpoints))
        for j in arange(1, numpoints):
            x[j] = x[j - 1] + length * cos(states[i, j])
            y[j] = y[j - 1] + length * sin(states[i, j])
        line.set_data(x, y)
        return time_text, rect, line,

    # call the animator function
    anim = animation.FuncAnimation(fig, animate, frames=len(t), init_func=init,
            interval=t[-1] / len(t) * 1000, blit=True, repeat=False)
    
    # save the animation if a filename is given
    if filename is not None:
        anim.save(filename, fps=30, codec='libx264')
        
##############

from matplotlib import animation
ani = animation.FuncAnimation(fig, updatefig, frames=1000, interval=75,
                              repeat=True, blit=True)

# video save information
metadata = dict(author='Isaac J. Yeaton',
                description='Standard and Otsu threholded images.')
Writer = animation.writers['avconv']
writer = Writer(fps=15)  # , extra_args=['-vcodec', 'libx264'], metadata=metadata)

if True:
    #ani.save('/home/isaac/Desktop/tmp1.mp4', writer=writer)
    ani.save('/home/isaac/Desktop/processed_shadowgraph_fields.mp4',
             writer=writer)

# %%
# check that the partial evaulation works
xx = x0
#xx = y.T[696]
arguments = np.hstack((param_vals, xx))


mm = M_func(*arguments)
ff = F_func(*arguments)

# this does not work...
# aargs = dict(zip(param_names, dummy_symbols, arguments))
# mm = M_func(*aargs)
# ff = F_func(*aargs)

print solve(mm, ff).flatten()
print lstsq(mm, ff)[0].flatten()




#part_args = dict(zip(param_names, param_vals))


print solve(mfunc(*xx), ffunc(*xx)).flatten()
# Out:
# [  0.           0.           0.         -58.78688199  88.03408696
#  -48.64785093]
# [  0.           0.           0.         -58.78688199  88.03408696
#  -48.64785093]
# [  0.           0.           0.         -58.78688199  88.03408696
#  -48.64785093]

# %%
frame0 = I.orientnew('frame0', 'Axis', [q[0], I.z])

mc0 = O.locatenew('mc0', q[1] * frame0.x)
mc0.v2pt_theory(O, I, frame0)

in0 = me.inertia(frame0, 0, 0, Izz[0])
body0 = me.RigidBody('body0', mc0, frame0, m[0], (in0, mc0))

frame1 = frame0.orientnew('frame1', 'Axis', [q[2], I.z])
frame2 = frame1.orientnew('frame2', 'Axis', [q[3], I.z])
frame1.set_ang_vel(I, u[2] * I.z)
frame2.set_ang_vel(I, u[3] * I.z)

in1 = me.inertia(frame1, 0, 0, Izz[1])
in2 = me.inertia(frame2, 0, 0, Izz[2])

# mc1 = mc0.locatenew('mc1', l[0] * frame0.x + 
#                            l[1] * sym.cos(q[2]) * frame1.x + 
#                            l[1] * sym.sin(q[2]) * frame1.y)
# mc2 = mc1.locatenew('mc2', l[1] * frame1.x + 
#                            l[2] * sym.cos(q[3]) * frame2.x +
#                            l[2] * sym.sin(q[3]) * frame2.y)

# after looking at the n-pendulum example
mc1 = mc0.locatenew('mc1', l[0] * frame0.x + l[1] * frame1.x)
mc2 = mc1.locatenew('mc2', l[1] * frame1.x + l[2] * frame2.x)
mc1.v2pt_theory(mc0, I, frame1)
mc2.v2pt_theory(mc1, I, frame2)

body1 = me.RigidBody('body1', mc1, frame1, m[1], (in1, mc1))
body2 = me.RigidBody('body2', mc2, frame2, m[2], (in2, mc2))

# each one might need four entries...
frames = [I, frame0, frame1, frame2]
points = [O, mc0, mc1, mc2]
bodies = [body0, body1, body2]
forces = [0, 0, 0]
kindiffs = [qq.diff(t) - uu for qq, uu in zip(q, u)]

# need to figure out forces and how to setup me.KanesMethod


# frames = [I]                              # List to hold the n + 1 frames
# points = [P0]                             # List to hold the n + 1 points
# particles = [Pa0]                         # List to hold the n + 1 particles
# forces = [(P0, f * I.x - m[0] * g * I.y)] # List to hold the n + 1 applied forces, including the input force, f
# kindiffs = [q[0].diff(t) - u[0]]          # List to hold kinematic ODE's
# for i in range(n):
#     Bi = I.orientnew('B' + str(i), 'Axis', [q[i + 1], I.z])   # Create a new frame
#     Bi.set_ang_vel(I, u[i + 1] * I.z)                         # Set angular velocity
#     frames.append(Bi)                                         # Add it to the frames list

#     Pi = points[-1].locatenew('P' + str(i + 1), l[i] * Bi.x)  # Create a new point
#     Pi.v2pt_theory(points[-1], I, Bi)                         # Set the velocity
#     points.append(Pi)                                         # Add it to the points list
    
#     Pai = Particle('Pa' + str(i + 1), Pi, m[i + 1])           # Create a new particle
#     particles.append(Pai)                                     # Add it to the particles list

#     forces.append((Pi, -m[i + 1] * g * I.y))                  # Set the force applied at the point
        
#     kindiffs.append(q[i + 1].diff(t) - u[i + 1])              # Define the kinematic ODE:  dq_i / dt - u_i = 0
